# %%
# import required libraries
import pandas as pd
import selenium
import time 
# import selenium webdriver
from selenium import webdriver
# importing required exceptions which need to handled
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
# importing regex
import re
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
driver = webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.happyfares.in/')
driver.maximize_window()

# %%
search_origin=driver.find_element(By.XPATH,'/html/body/div[2]/main/div/div[1]/div/div[1]/div/div/div[2]/div/form/div[1]/div/div[1]/div/div/div/input')
search_origin.send_keys("DELHI(DEL)")

# %%
search_destination= driver.find_element(By.XPATH,'/html/body/div[2]/main/div/div[1]/div/div[1]/div/div/div[2]/div/form/div[1]/div/div[2]/div/div/div/input')
search_destination.send_keys('CHENNAI(MAA)')

# %%
search_btn = driver.find_element(By.XPATH,'//input[@class="btn btn-primary shadow-none text-uppercase px-0 py-2 w-100 font-weight-600"]')
search_btn.click()

# %%
next_day_btn=driver.find_element(By.XPATH,'//BUTTON[@class="btn btn-primary shadow-none btn-sm valign-wrapper pr-0"]')
next_day_btn.click()

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 d-inline d-lg-block responsive-bold ng-binding"]')
    for i in airline_tag[0:130]:
        airline.append(i.text.split("|")[1])
except NoSuchElementException:
    airline.append('-')    

airline
# Out:
# [' SpiceJet',
#  ' Go First',
#  ' Go First',
#  ' Go First',
#  ' Go First',
#  ' IndiGo',
#  ' AirAsia India',
#  ' AirAsia India',
#  ' AirAsia India',
#  ' IndiGo',
#  ' IndiGo',
#  ' IndiGo',
#  ' IndiGo',
#  ' SpiceJet',
#  ' SpiceJet',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' IndiGo',
#  ' IndiGo',
#  ' IndiGo',
#  ' Vistara',
#  ' Air India',
#  ' Air India',
#  ' IndiGo',
#  ' SpiceJet',
#  ' AirAsia India',
#  ' IndiGo',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' SpiceJet',
#  ' SpiceJet',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' SpiceJet',
#  ' SpiceJet',
#  ' IndiGo',
#  ' SpiceJet',
#  ' SpiceJet',
#  ' Vistara',
#  ' Vistara',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' Air India',
#  ' IndiGo',
#  ' AirAsia India',
#  ' AirAsia India',
# ...

# %%
date = []
try:
    date_tag = driver.find_elements(By.XPATH,'//p[@class="hide-on-small-and-down mb-0 ng-binding lbl-xmedium"]')
    for i in date_tag:
        date.append(i.text.split(',')[1])
except NoSuchElementException:
    date.append('-')    

Date=date[1:260:2]

# %%
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="slb-small mb-0 text-nowrap ng-binding"]')
    for i in source_tag:
        source.append(i.text.split('(')[0])
except NoSuchElementException:
    source.append('-')    

Source=source[0:260:2]

# %%
destination = source[1:260:2]
destination
# Out:
# ['CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI',
#  'CHENNAI',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
#  'CHENNAI ',
# ...

# %%
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 lbl-bold ng-binding lbl-huge"]')
    for i in dep_time_tag:
        dep_time.append(i.text.split('+')[0])
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:260:2]

# %%
arrival_time=dep_time[1:260:2]
arrival_time
# Out:
# ['21:30',
#  '07:35 ',
#  '07:35 ',
#  '07:35 ',
#  '07:35 ',
#  '00:55 ',
#  '06:10 ',
#  '06:10 ',
#  '08:35 ',
#  '10:05',
#  '11:20',
#  '13:15',
#  '00:10 ',
#  '08:00 ',
#  '08:00 ',
#  '22:35',
#  '15:05',
#  '15:10',
#  '14:10 ',
#  '14:10 ',
#  '14:10 ',
#  '15:10',
#  '22:10',
#  '02:40 ',
#  '10:25',
#  '15:10',
#  '14:10 ',
#  '18:55',
#  '08:00',
#  '17:05',
#  '20:15',
#  '15:10',
#  '08:50',
#  '12:35',
#  '14:10 ',
#  '03:05 ',
#  '03:05 ',
#  '07:25 ',
#  '07:25 ',
#  '07:25 ',
#  '07:25 ',
#  '07:25 ',
#  '07:25 ',
#  '07:25 ',
#  '20:45',
#  '20:45',
#  '07:05',
#  '18:30',
#  '22:35',
#  '22:40',
#  '16:20',
#  '07:25 ',
#  '07:25 ',
#  '19:25 ',
#  '19:25 ',
#  '19:25 ',
#  '19:25 ',
#  '15:10',
#  '06:10 ',
#  '08:35 ',
#  '20:20',
#  '21:25',
#  '19:15',
#  '11:50 ',
#  '14:10 ',
#  '11:50 ',
#  '01:05 ',
#  '11:50 ',
#  '08:35 ',
#  '11:50',
#  '19:50',
#  '22:45',
#  '15:20',
#  '20:25',
#  '02:45 ',
#  '19:50',
#  '19:50',
#  '19:50',
#  '19:50 ',
# ...

# %%
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="responsive-dblock ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
duration
# Out:
# ['02h : 40m',
#  '13h : 35m',
#  '11h : 35m',
#  '10h : 35m',
#  '09h : 05m',
#  '05h : 35m',
#  '13h : 40m',
#  '08h : 50m',
#  '11h : 15m',
#  '02h : 55m',
#  '02h : 55m',
#  '02h : 45m',
#  '03h : 00m',
#  '13h : 50m',
#  '12h : 00m',
#  '02h : 55m',
#  '03h : 15m',
#  '05h : 25m',
#  '17h : 00m',
#  '18h : 45m',
#  '22h : 35m',
#  '03h : 00m',
#  '02h : 50m',
#  '02h : 50m',
#  '02h : 45m',
#  '09h : 00m',
#  '21h : 10m',
#  '03h : 00m',
#  '06h : 00m',
#  '08h : 55m',
#  '03h : 00m',
#  '07h : 10m',
#  '03h : 05m',
#  '02h : 50m',
#  '20h : 00m',
#  '17h : 45m',
#  '09h : 30m',
#  '08h : 55m',
#  '10h : 05m',
#  '11h : 25m',
#  '21h : 15m',
#  '21h : 25m',
#  '23h : 25m',
#  '24h : 25m',
#  '18h : 45m',
#  '13h : 45m',
#  '05h : 10m',
#  '05h : 45m',
#  '05h : 45m',
#  '02h : 30m',
#  '02h : 40m',
#  '13h : 35m',
#  '12h : 25m',
#  '20h : 55m',
#  '22h : 05m',
#  '23h : 25m',
#  '25h : 35m',
#  '05h : 55m',
#  '11h : 05m',
#  '13h : 30m',
#  '02h : 45m',
#  '05h : 45m',
# ...

# %%
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//div[@class="col-4 col-md-3 sxlb-small"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text.split('m')[1])
except NoSuchElementException:
    Total_Stops.append('-')    
Total_Stops
# Out:
# [' Non- Stop',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' Non- Stop',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' Non- Stop',
#  ' 1 - Change',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' Non- Stop',
#  ' Non- Stop',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
#  ' 1 - Change',
# ...

# %%
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//p[@class="font-weight-600 text-gray lbl-bold roboto_font mb-0 ng-binding ng-scope lbl-huge"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')    

price
# Out:
# ['₹ 6242',
#  '₹ 6417',
#  '₹ 6417',
#  '₹ 6417',
#  '₹ 6417',
#  '₹ 6449',
#  '₹ 6615',
#  '₹ 6615',
#  '₹ 6615',
#  '₹ 6616',
#  '₹ 6616',
#  '₹ 6616',
#  '₹ 6616',
#  '₹ 6618',
#  '₹ 6618',
#  '₹ 6690',
#  '₹ 6690',
#  '₹ 6785',
#  '₹ 6785',
#  '₹ 6785',
#  '₹ 6785',
#  '₹ 6931',
#  '₹ 6931',
#  '₹ 6931',
#  '₹ 6932',
#  '₹ 7047',
#  '₹ 7047',
#  '₹ 7246',
#  '₹ 7378',
#  '₹ 7529',
#  '₹ 7561',
#  '₹ 7887',
#  '₹ 8055',
#  '₹ 8580',
#  '₹ 8727',
#  '₹ 8847',
#  '₹ 8847',
#  '₹ 8895',
#  '₹ 8895',
#  '₹ 8895',
#  '₹ 8895',
#  '₹ 8895',
#  '₹ 8895',
#  '₹ 8895',
#  '₹ 8955',
#  '₹ 8955',
#  '₹ 8975',
#  '₹ 9231',
#  '₹ 9290',
#  '₹ 9315',
#  '₹ 9315',
#  '₹ 9420',
#  '₹ 9424',
#  '₹ 9424',
#  '₹ 9424',
#  '₹ 9424',
#  '₹ 9424',
#  '₹ 10068',
#  '₹ 10072',
#  '₹ 10072',
#  '₹ 10155',
#  '₹ 10463',
#  '₹ 10599',
#  '₹ 10701',
#  '₹ 11238',
#  '₹ 11751',
#  '₹ 11992',
#  '₹ 12099',
#  '₹ 12224',
#  '₹ 12276',
#  '₹ 12276',
#  '₹ 12307',
#  '₹ 12622',
#  '₹ 12622',
#  '₹ 12779',
# ...

# %%
print(len(airline),len(Date),len(Source),len(destination),len(Dep_time),len(arrival_time),len(duration),len(Total_Stops),len(price))
# Out:
# 130 130 130 130 130 130 130 130 130

# %%
df1=pd.DataFrame({'Airlines':airline,'Date of journey':Date,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})
df1
# Out:
#        Airlines Date of journey  Source Destination Departure Time  \
# 0      SpiceJet     10 Jan 2023  DELHI     CHENNAI           18:50
# 1      Go First     11 Jan 2023  DELHI     CHENNAI           18:00
# 2      Go First     11 Jan 2023  DELHI     CHENNAI           20:00
# 3      Go First     11 Jan 2023  DELHI     CHENNAI           21:00
# 4      Go First     11 Jan 2023  DELHI     CHENNAI           22:30
# ..          ...             ...     ...         ...            ...
# 125   Air India     11 Jan 2023  DELHI     CHENNAI           20:15
# 126   Air India     11 Jan 2023  DELHI     CHENNAI           17:00
# 127     Vistara     10 Jan 2023  DELHI     CHENNAI           13:25
# 128   Air India     10 Jan 2023  DELHI     CHENNAI           12:10
# 129     Vistara     10 Jan 2023  DELHI     CHENNAI           13:20
#
#     Arrival Time   Durtaion  Total Stops    Price
# 0          21:30  02h : 40m    Non- Stop   ₹ 6242
# 1         07:35   13h : 35m   1 - Change   ₹ 6417
# ...

# %%
df1.to_csv('happyfare.csv')

# %%
# import required libraries
import pandas as pd
import selenium
import time 
# import selenium webdriver
from selenium import webdriver
# importing required exceptions which need to handled
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
# importing regex
import re
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
driver = webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.happyfares.in/')
driver.maximize_window()
search_origin=driver.find_element(By.XPATH,'/html/body/div[2]/main/div/div[1]/div/div[1]/div/div/div[2]/div/form/div[1]/div/div[1]/div/div/div/input')
search_origin.send_keys('Mumbai')
search_destination= driver.find_element(By.XPATH,'/html/body/div[2]/main/div/div[1]/div/div[1]/div/div/div[2]/div/form/div[1]/div/div[2]/div/div/div/input')
search_destination.send_keys('Ahemdabad')

# %%
search_btn = driver.find_element(By.XPATH,'/html/body/div[2]/main/div/div[1]/div/div[1]/div/div/div[2]/div/div[6]/div/input')
search_btn.click()

# %%
next_day_btn=driver.find_element(By.XPATH,'//BUTTON[@class="btn btn-primary shadow-none btn-sm valign-wrapper pr-0"]')
next_day_btn.click()

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 d-inline d-lg-block responsive-bold ng-binding"]')
    for i in airline_tag:
        airline.append(i.text.split("|")[1])
except NoSuchElementException:
    airline.append('-')    

len(airline)
# Out:
# 61

# %%
date = []
try:
    date_tag = driver.find_elements(By.XPATH,'//p[@class="hide-on-small-and-down mb-0 ng-binding lbl-xmedium"]')
    for i in date_tag:
        date.append(i.text.split(',')[1])
except NoSuchElementException:
    date.append('-')    

Date=date[1:68:2] 
len(Date)
# Out:
# 34

# %%
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="slb-small mb-0 text-nowrap ng-binding"]')
    for i in source_tag:
        source.append(i.text.split('(')[0])
except NoSuchElementException:
    source.append('-')    

Source=source[0:68:2]

# %%
destination = source[1:68:2]

# %%
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 lbl-bold ng-binding lbl-huge"]')
    for i in dep_time_tag:
        dep_time.append(i.text.split('+')[0])
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:68:2]
arrival_time=dep_time[1:68:2]

# %%
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="responsive-dblock ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
len(duration)
# Out:
# 34

# %%
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//div[@class="col-4 col-md-3 sxlb-small"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text.split('m')[1])
except NoSuchElementException:
    Total_Stops.append('-')    
len(Total_Stops)
# Out:
# 34

# %%
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//p[@class="font-weight-600 text-gray lbl-bold roboto_font mb-0 ng-binding ng-scope lbl-huge"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')    

len(price)
# Out:
# 34

# %%
df2=pd.DataFrame({'Airlines':airline,'Date of journey':Date,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})
df2
# Out:
#           Airlines Date of journey   Source Destination Departure Time  \
# 0         Go First     27 Feb 2023  MUMBAI      JAIPUR           05:40
# 1         Go First     27 Feb 2023  MUMBAI      JAIPUR           15:35
# 2    AirAsia India     27 Feb 2023  MUMBAI       JAIPUR          15:15
# 3    AirAsia India     27 Feb 2023  MUMBAI       JAIPUR          06:40
# 4          Vistara     27 Feb 2023  MUMBAI      JAIPUR           11:45
# 5           IndiGo     27 Feb 2023  MUMBAI      JAIPUR           08:05
# 6           IndiGo     27 Feb 2023  MUMBAI      JAIPUR           15:40
# 7           IndiGo     27 Feb 2023  MUMBAI      JAIPUR           20:40
# 8           IndiGo     28 Feb 2023  MUMBAI      JAIPUR           23:30
# 9        Air India     27 Feb 2023  MUMBAI      JAIPUR           11:20
# 10         Vistara     27 Feb 2023  MUMBAI      JAIPUR           17:40
# 11        SpiceJet     27 Feb 2023  MUMBAI      JAIPUR           06:10
# ...

# %%
df2.to_csv('february.csv')

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 d-inline d-lg-block responsive-bold ng-binding"]')
    for i in airline_tag:
        airline.append(i.text.split("|")[1])
except NoSuchElementException:
    airline.append('-')    
date = []
try:
    date_tag = driver.find_elements(By.XPATH,'//p[@class="hide-on-small-and-down mb-0 ng-binding lbl-xmedium"]')
    for i in date_tag:
        date.append(i.text.split(',')[1])
except NoSuchElementException:
    date.append('-')    

Date=date[1:168:2] 
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="slb-small mb-0 text-nowrap ng-binding"]')
    for i in source_tag:
        source.append(i.text.split('(')[0])
except NoSuchElementException:
    source.append('-')    

Source=source[0:168:2]
destination = source[1:168:2]
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 lbl-bold ng-binding lbl-huge"]')
    for i in dep_time_tag:
        dep_time.append(i.text.split('+')[0])
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:168:2]
arrival_time=dep_time[1:168:2]
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="responsive-dblock ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//div[@class="col-4 col-md-3 sxlb-small"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text.split('m')[1])
except NoSuchElementException:
    Total_Stops.append('-')    
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//p[@class="font-weight-600 text-gray lbl-bold roboto_font mb-0 ng-binding ng-scope lbl-huge"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')

# %%
print(len(airline),len(Date),len(Source),len(destination),len(Dep_time),len(arrival_time),len(duration),len(Total_Stops),len(price))
# Out:
# 84 84 84 84 84 84 84 84 84

# %%
df3=pd.DataFrame({'Airlines':airline,'Date of journey':Date,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})
df3
# Out:
#           Airlines Date of journey   Source Destination Departure Time  \
# 0           IndiGo     19 Mar 2023  KOLKATA  NORTH GOA           01:10
# 1    AirAsia India     19 Mar 2023  KOLKATA         GOA          08:10
# 2    AirAsia India     20 Mar 2023  KOLKATA         GOA          16:00
# 3    AirAsia India     20 Mar 2023  KOLKATA         GOA          16:00
# 4    AirAsia India     20 Mar 2023  KOLKATA         GOA          20:15
# ..             ...             ...      ...         ...            ...
# 79       Air India     20 Mar 2023  KOLKATA         GOA          10:30
# 80       Air India     21 Mar 2023  KOLKATA         GOA          20:00
# 81       Air India     20 Mar 2023  KOLKATA         GOA          20:00
# 82       Air India     20 Mar 2023  KOLKATA         GOA          07:00
# 83       Air India     19 Mar 2023  KOLKATA         GOA          07:00
#
#    Arrival Time   Durtaion  Total Stops    Price
# 0         06:45  05h : 35m   1 - Change   ₹ 7717
# ...

# %%
df3.to_csv('MARCH.csv')

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 d-inline d-lg-block responsive-bold ng-binding"]')
    for i in airline_tag:
        airline.append(i.text.split("|")[1])
except NoSuchElementException:
    airline.append('-')    
date = []
try:
    date_tag = driver.find_elements(By.XPATH,'//p[@class="hide-on-small-and-down mb-0 ng-binding lbl-xmedium"]')
    for i in date_tag:
        date.append(i.text.split(',')[1])
except NoSuchElementException:
    date.append('-')    

Date=date[1:130:2] 
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="slb-small mb-0 text-nowrap ng-binding"]')
    for i in source_tag:
        source.append(i.text.split('(')[0])
except NoSuchElementException:
    source.append('-')    

Source=source[0:130:2]
destination = source[1:130:2]
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 lbl-bold ng-binding lbl-huge"]')
    for i in dep_time_tag:
        dep_time.append(i.text.split('+')[0])
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:130:2]
arrival_time=dep_time[1:130:2]
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="responsive-dblock ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//div[@class="col-4 col-md-3 sxlb-small"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text.split('\n')[1])
except NoSuchElementException:
    Total_Stops.append('-')    
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//p[@class="font-weight-600 text-gray lbl-bold roboto_font mb-0 ng-binding ng-scope lbl-huge"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')

# %%
print(len(airline),len(Date),len(Source),len(destination),len(Dep_time),len(arrival_time),len(duration),len(Total_Stops),len(price))
# Out:
# 65 65 65 65 65 65 65 65 65

# %%
df4=pd.DataFrame({'Airlines':airline,'Date of journey':Date,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})
df4
# Out:
#           Airlines Date of journey    Source Destination Departure Time  \
# 0        Air India     13 May 2023  GUWAHATI    CHENNAI           15:25
# 1    AirAsia India     12 May 2023  GUWAHATI     CHENNAI          11:50
# 2    AirAsia India     13 May 2023  GUWAHATI     CHENNAI          21:15
# 3    AirAsia India     13 May 2023  GUWAHATI     CHENNAI          21:15
# 4        Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# 5        Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# 6        Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# 7        Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# 8        Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# 9        Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# 10       Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# 11       Air India     13 May 2023  GUWAHATI    CHENNAI           15:55
# ...

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 d-inline d-lg-block responsive-bold ng-binding"]')
    for i in airline_tag:
        airline.append(i.text.split("|")[1])
except NoSuchElementException:
    airline.append('-')    
date = []
try:
    date_tag = driver.find_elements(By.XPATH,'//p[@class="hide-on-small-and-down mb-0 ng-binding lbl-xmedium"]')
    for i in date_tag:
        date.append(i.text.split(',')[1])
except NoSuchElementException:
    date.append('-')    

Date=date[1:276:2] 
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="slb-small mb-0 text-nowrap ng-binding"]')
    for i in source_tag:
        source.append(i.text.split('(')[0])
except NoSuchElementException:
    source.append('-')    

Source=source[0:276:2]
destination = source[1:276:2]
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 lbl-bold ng-binding lbl-huge"]')
    for i in dep_time_tag:
        dep_time.append(i.text.split('+')[0])
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:276:2]
arrival_time=dep_time[1:276:2]
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="responsive-dblock ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//div[@class="col-4 col-md-3 sxlb-small"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text.split('\n')[1])
except NoSuchElementException:
    Total_Stops.append('-')    
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//p[@class="font-weight-600 text-gray lbl-bold roboto_font mb-0 ng-binding ng-scope lbl-huge"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')

# %%
print(len(airline),len(Date),len(Source),len(destination),len(Dep_time),len(arrival_time),len(duration),len(Total_Stops),len(price))
# Out:
# 138 138 138 138 138 138 138 138 138

# %%
df5=pd.DataFrame({'Airlines':airline,'Date of journey':Date,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})
df5
# Out:
#            Airlines Date of journey  Source Destination Departure Time  \
# 0           Vistara     17 Jun 2023  DELHI          GOA          11:10
# 1          Go First     17 Jun 2023  DELHI          GOA          20:30
# 2            IndiGo     17 Jun 2023  DELHI          GOA          10:00
# 3            IndiGo     17 Jun 2023  DELHI          GOA          11:00
# 4            IndiGo     17 Jun 2023  DELHI          GOA          12:15
# 5            IndiGo     17 Jun 2023  DELHI          GOA          16:15
# 6            IndiGo     17 Jun 2023  DELHI          GOA          19:00
# 7            IndiGo     18 Jun 2023  DELHI          GOA          21:45
# 8            IndiGo     17 Jun 2023  DELHI   NORTH GOA           07:55
# 9          Go First     17 Jun 2023  DELHI          GOA          07:00
# 10         Go First     17 Jun 2023  DELHI          GOA          08:00
# 11         Go First     17 Jun 2023  DELHI          GOA          08:00
# ...

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 d-inline d-lg-block responsive-bold ng-binding"]')
    for i in airline_tag:
        airline.append(i.text.split("|")[1])
except NoSuchElementException:
    airline.append('-')    
date = []
try:
    date_tag = driver.find_elements(By.XPATH,'//p[@class="hide-on-small-and-down mb-0 ng-binding lbl-xmedium"]')
    for i in date_tag:
        date.append(i.text.split(',')[1])
except NoSuchElementException:
    date.append('-')    

Date=date[1:288:2] 
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="slb-small mb-0 text-nowrap ng-binding"]')
    for i in source_tag:
        source.append(i.text.split('(')[0])
except NoSuchElementException:
    source.append('-')    

Source=source[0:288:2]
destination = source[1:288:2]
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 lbl-bold ng-binding lbl-huge"]')
    for i in dep_time_tag:
        dep_time.append(i.text.split('+')[0])
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:288:2]
arrival_time=dep_time[1:288:2]
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="responsive-dblock ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//div[@class="col-4 col-md-3 sxlb-small"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text.split('\n')[1])
except NoSuchElementException:
    Total_Stops.append('-')    
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//p[@class="font-weight-600 text-gray lbl-bold roboto_font mb-0 ng-binding ng-scope lbl-huge"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')

# %%
print(len(airline),len(Date),len(Source),len(destination),len(Dep_time),len(arrival_time),len(duration),len(Total_Stops),len(price))
# Out:
# 144 144 144 144 144 144 144 144 144

# %%
df6=pd.DataFrame({'Airlines':airline,'Date of journey':Date,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})
df6
# Out:
#            Airlines Date of journey   Source Destination Departure Time  \
# 0         Air India     18 Aug 2023  MUMBAI    HYDERABAD          06:45
# 1         Air India     18 Aug 2023  MUMBAI    HYDERABAD          11:00
# 2         Air India     18 Aug 2023  MUMBAI    HYDERABAD          20:10
# 3           Vistara     18 Aug 2023  MUMBAI    HYDERABAD          06:15
# 4           Vistara     19 Aug 2023  MUMBAI    HYDERABAD          22:40
# 5           Vistara     18 Aug 2023  MUMBAI    HYDERABAD          10:40
# 6           Vistara     18 Aug 2023  MUMBAI    HYDERABAD          19:20
# 7           Vistara     19 Aug 2023  MUMBAI    HYDERABAD          21:00
# 8     AirAsia India     19 Aug 2023  MUMBAI    HYDERABAD          19:40
# 9     AirAsia India     19 Aug 2023  MUMBAI    HYDERABAD          20:35
# 10    AirAsia India     19 Aug 2023  MUMBAI    HYDERABAD          23:10
# 11          Vistara     19 Aug 2023  MUMBAI    HYDERABAD          21:00
# ...

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 d-inline d-lg-block responsive-bold ng-binding"]')
    for i in airline_tag:
        airline.append(i.text.split("|")[1])
except NoSuchElementException:
    airline.append('-')    
date = []
try:
    date_tag = driver.find_elements(By.XPATH,'//p[@class="hide-on-small-and-down mb-0 ng-binding lbl-xmedium"]')
    for i in date_tag:
        date.append(i.text.split(',')[1])
except NoSuchElementException:
    date.append('-')    

Date=date[1:122:2] 
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="slb-small mb-0 text-nowrap ng-binding"]')
    for i in source_tag:
        source.append(i.text.split('(')[0])
except NoSuchElementException:
    source.append('-')    

Source=source[0:122:2]
destination = source[1:122:2]
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//p[@class="mb-0 lbl-bold ng-binding lbl-huge"]')
    for i in dep_time_tag:
        dep_time.append(i.text.split('+')[0])
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:122:2]
arrival_time=dep_time[1:122:2]
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="responsive-dblock ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//div[@class="col-4 col-md-3 sxlb-small"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text.split('m')[1])
except NoSuchElementException:
    Total_Stops.append('-')    
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//p[@class="font-weight-600 text-gray lbl-bold roboto_font mb-0 ng-binding ng-scope lbl-huge"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')

# %%
print(len(airline),len(Date),len(Source),len(destination),len(Dep_time),len(arrival_time),len(duration),len(Total_Stops),len(price))
# Out:
# 61 61 61 61 61 61 61 61 61

# %%
df7=pd.DataFrame({'Airlines':airline,'Date of journey':Date,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})
df7
# Out:
#       Airlines Date of journey   Source Destination Departure Time  \
# 0     Go First     02 Feb 2023  MUMBAI   AHMEDABAD           07:50
# 1     Go First     02 Feb 2023  MUMBAI   AHMEDABAD           13:30
# 2     Go First     02 Feb 2023  MUMBAI   AHMEDABAD           17:15
# 3     Go First     02 Feb 2023  MUMBAI   AHMEDABAD           22:40
# 4    Akasa Air     02 Feb 2023  MUMBAI   AHMEDABAD           05:40
# 5    Akasa Air     02 Feb 2023  MUMBAI   AHMEDABAD           09:50
# 6    Akasa Air     02 Feb 2023  MUMBAI   AHMEDABAD           14:10
# 7      Vistara     02 Feb 2023  MUMBAI   AHMEDABAD           15:20
# 8       IndiGo     02 Feb 2023  MUMBAI   AHMEDABAD           16:50
# 9      Vistara     02 Feb 2023  MUMBAI   AHMEDABAD           22:40
# 10      IndiGo     02 Feb 2023  MUMBAI   AHMEDABAD           18:35
# 11      IndiGo     02 Feb 2023  MUMBAI   AHMEDABAD           20:25
# 12      IndiGo     02 Feb 2023  MUMBAI   AHMEDABAD           00:30
# ...

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16],axis=0)

# %%
pd.set_option('display.max_rows',None)

# %%
df=df.reset_index()

# %%
df.drop(['index'],axis=1,inplace =True)

# %%
df
# Out:
#             Airlines Date of journey    Source Destination Departure Time  \
# 0           SpiceJet     10 Jan 2023    DELHI     CHENNAI           18:50
# 1           Go First     11 Jan 2023    DELHI     CHENNAI           18:00
# 2           Go First     11 Jan 2023    DELHI     CHENNAI           20:00
# 3           Go First     11 Jan 2023    DELHI     CHENNAI           21:00
# 4           Go First     11 Jan 2023    DELHI     CHENNAI           22:30
# 5             IndiGo     11 Jan 2023    DELHI     CHENNAI           19:20
# 6      AirAsia India     11 Jan 2023    DELHI      CHENNAI          16:30
# 7      AirAsia India     11 Jan 2023    DELHI      CHENNAI          21:20
# 8      AirAsia India     11 Jan 2023    DELHI      CHENNAI          21:20
# 9             IndiGo     10 Jan 2023    DELHI     CHENNAI           07:10
# 10            IndiGo     10 Jan 2023    DELHI     CHENNAI           08:25
# 11            IndiGo     10 Jan 2023    DELHI     CHENNAI           10:30
# ...

# %%
df.to_csv('flight_price.csv')

# %%
# import required libraries
import pandas as pd
import selenium
import time 
# import selenium webdriver
from selenium import webdriver
# importing required exceptions which need to handled
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
# importing regex
import re
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
driver = webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https://www.easemytrip.com/flights.html')
driver.maximize_window()

# %%
search_origin=driver.find_element(By.XPATH,'/html/body/div[6]/div[3]/div/div[2]/div/div[1]/div[1]/input[2]')
search_origin.send_keys('amritsar')

# %%
search_destination= driver.find_element(By.XPATH,'/html/body/div[6]/div[3]/div/div[2]/div/div[3]/div[1]/input[2]')
search_destination.send_keys('goa')

# %%
search_btn = driver.find_element(By.XPATH,'//button[@class="srchBtnSe"]')
search_btn.click()

# %%
airline = []
try:
    airline_tag = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')
    for i in airline_tag:
        airline.append(i.text)
except NoSuchElementException:
    airline.append('-')    
source = []
try:
    source_tag = driver.find_elements(By.XPATH,'//span[@class="txt-r3-n ng-binding"]')
    for i in source_tag:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')    

Source=source[0:164:2]
destination = source[1:164:2]
dep_time = []
try:
    dep_time_tag = driver.find_elements(By.XPATH,'//span[@class="txt-r2-n ng-binding"]')
    for i in dep_time_tag:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('-')    

Dep_time=dep_time[0:164:2]
arrival_time=dep_time[1:164:2]
duration= []
try:
    duration_tag = driver.find_elements(By.XPATH,'//span[@class="dura_md ng-binding"]')
    for i in duration_tag:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('-')    
Total_Stops= []
try:
    Total_Stops_tag = driver.find_elements(By.XPATH,'//span[@class="dura_md2 ng-scope"]')
    for i in Total_Stops_tag:
        Total_Stops.append(i.text)
except NoSuchElementException:
    Total_Stops.append('-')

# %%
price = []
try:
    price_tag = driver.find_elements(By.XPATH,'//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')
    for i in price_tag:
        price.append(i.text)
except NoSuchElementException:
    price.append('-')

# %%
print(len(airline),len(Source),len(destination),len(Dep_time),len(arrival_time),len(duration),len(Total_Stops),len(price))
# Out:
# 82 82 82 82 82 82 82 82

# %%
df16=pd.DataFrame({'Airlines':airline,'Source':Source,'Destination':destination,'Departure Time':Dep_time,'Arrival Time':arrival_time,'Durtaion':duration,'Total Stops':Total_Stops,'Price':price})

# %%
import numpy as np
df16['Date of journey']=np.nan

# %%
df8['Date of journey']='14 aug 2023'

# %%
df8
# Out:
#      Airlines Source Destination Departure Time Arrival Time Durtaion  \
# 0     Vistara  Delhi    Amritsar          08:00        09:10  01h 10m
# 1   Air India  Delhi    Amritsar          14:15        15:25  01h 10m
# 2   Air India  Delhi    Amritsar          21:15        22:25  01h 10m
# 3     Vistara  Delhi    Amritsar          13:40        14:50  01h 10m
# 4      Indigo  Delhi    Amritsar          10:10        11:10  01h 00m
# 5      Indigo  Delhi    Amritsar          17:20        18:35  01h 15m
# 6      Indigo  Delhi    Amritsar          22:10        23:25  01h 15m
# 7      Indigo  Delhi    Amritsar          10:05        15:35  05h 30m
# 8      Indigo  Delhi    Amritsar          08:45        15:35  06h 50m
# 9      Indigo  Delhi    Amritsar          07:30        15:35  08h 05m
# 10  Air India  Delhi    Amritsar          22:30        08:35  10h 05m
# 11  Air India  Delhi    Amritsar          21:15        08:35  11h 20m
# ...

# %%
df16['Price']=df16['Price'].replace("",np.nan)

# %%
df16['Price']=df16['Price'].replace(np.nan,'8,233')

# %%
df16
# Out:
#      Airlines    Source Destination Departure Time Arrival Time Durtaion  \
# 0      Indigo  Amritsar         Goa          11:40        21:30  09h 50m
# 1      Indigo  Amritsar         Goa          12:20        18:00  05h 40m
# 2      Indigo  Amritsar         Goa          16:10        22:40  06h 30m
# 3    GO FIRST  Amritsar         Goa          11:20        16:40  05h 20m
# 4    GO FIRST  Amritsar         Goa          20:45        06:10  09h 25m
# 5    GO FIRST  Amritsar         Goa          11:20        23:35  12h 15m
# 6   Air India  Amritsar         Goa          09:05        14:35  05h 30m
# 7   Air India  Amritsar         Goa          09:05        22:20  13h 15m
# 8      Indigo  Amritsar         Goa          11:40        18:40  07h 00m
# 9      Indigo  Amritsar         Goa          22:45        01:35  02h 50m
# 10    Vistara  Amritsar         Goa          09:45        21:20  11h 35m
# 11     Indigo  Amritsar         Goa          08:55        18:10  09h 15m
# ...
